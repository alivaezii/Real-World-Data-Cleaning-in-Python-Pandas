# %% [markdown]
# ## Import Library

# %%
import pandas as pd

# %% [markdown]
# ## Import CSV

# %%
df = pd.read_csv('HighestCareerBattingAverageInTests.csv')
df.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1  PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
#
#       SR  100  50  0    4s  6s
# 0  58.60   29  13  7  626+   6
# 1  64.38    5   4  -   123  23
# 2  55.68    5   4  2   186   5
# 3  54.48    7  11  1  246+  11
# 4  56.00   10   5  2  104+   1

# %% [markdown]
# ## Rename Multiple Columns in a list

# %%
df = df.rename(columns= {'Mat':'Matches','No' : 'Not_Outs', 'HS': 'Highest_Inns_Score', 'BF': 'Balls_Faced', 'SR': 'Batting_Strike_Rate'})
df.head()
# Out:
#              Player       Span  Matches  Inns  NO  Runs Highest_Inns_Score  \
# 0  DG Bradman (AUS)  1928-1948       52    80  10  6996                334
# 1  PHKD Mendis (SL)  2022-2025       12    21   2  1184               182*
# 2    AC Voges (AUS)  2015-2016       20    31   7  1485               269*
# 3   RG Pollock (SA)  1963-1970       23    41   4  2256                274
# 4   GA Headley (WI)  1930-1954       22    40   4  2190               270*
#
#      Ave Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s
# 0  99.94       9800+                58.60   29  13  7  626+   6
# 1  62.31        1839                64.38    5   4  -   123  23
# 2  61.87        2667                55.68    5   4  2   186   5
# 3  60.97       1707+                54.48    7  11  1  246+  11
# 4  60.83        416+                56.00   10   5  2  104+   1

# %% [markdown]
# ## Check Null Values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# NO                     False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna() == 1]
# Out:
#                   Player       Span  Matches  Inns  NO  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81   5  4455
# 16       CL Walcott (WI)  1948-1960       44    74   7  3798
# 58  Hon.FS Jackson (ENG)  1893-1905       20    33   4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 8                 207  58.61         NaN                  NaN   15  19  6
# 16                220  56.68         NaN                  0.0   15  14  1
# 58               144*  48.79         NaN                  0.0    5   6  3
#
#       4s  6s
# 8   258+   2
# 16  107+  11
# 58   51+   0

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
df[df['Player'] == 'ED Weekes (WI)']
# Out:
#            Player       Span  Matches  Inns  NO  Runs Highest_Inns_Score  \
# 8  ED Weekes (WI)  1948-1958       48    81   5  4455                207
#
#      Ave Balls_Faced  Batting_Strike_Rate  100  50  0    4s 6s
# 8  58.61           0                  0.0   15  19  6  258+  2

# %%
df[df['Player'] == 'CL Walcott (WI)']
# Out:
#              Player       Span  Matches  Inns  NO  Runs Highest_Inns_Score  \
# 16  CL Walcott (WI)  1948-1960       44    74   7  3798                220
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s
# 16  56.68           0                  0.0   15  14  1  107+  11

# %%
df[df['Player'] == 'Hon.FS Jackson (ENG)']
# Out:
#                   Player       Span  Matches  Inns  NO  Runs  \
# 58  Hon.FS Jackson (ENG)  1893-1905       20    33   4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 58               144*  48.79           0                  0.0    5   6  3
#
#      4s 6s
# 58  51+  0

# %% [markdown]
# ## Drop duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df[df['Player'].duplicated() == 1]
# Out:
#                 Player       Span  Matches  Inns  NO   Runs  \
# 13  KC Sangakkara (SL)  2000-2015      134   233  17  12400
# 21  KS Williamson (NZ)  2010-2024      105   186  17   9276
# 38  S Chanderpaul (WI)  1994-2015      164   280  49  11867
# 48   DCS Compton (ENG)  1937-1957       78   131  15   5807
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 13                319  57.40       22882                54.19   38  52  11
# 21                251  54.88       17913                51.78   33  37  11
# 38               203*  51.37       27395                43.31   30  66  15
# 48                278  50.06       2731+                38.81   17  28  10
#
#       4s  6s
# 13  1491  51
# 21  1031  27
# 38  1285  36
# 48  342+   3

# %%
df[df['Player'].isin(['KC Sangakkara (SL)', 'KS Williamson (NZ)', 'S Chanderpaul (WI)', 'DCS Compton (ENG)'])]
# Out:
#                 Player       Span  Matches  Inns  NO   Runs  \
# 12  KC Sangakkara (SL)  2000-2015      134   233  17  12400
# 13  KC Sangakkara (SL)  2000-2015      134   233  17  12400
# 20  KS Williamson (NZ)  2010-2024      105   186  17   9276
# 21  KS Williamson (NZ)  2010-2024      105   186  17   9276
# 37  S Chanderpaul (WI)  1994-2015      164   280  49  11867
# 38  S Chanderpaul (WI)  1994-2015      164   280  49  11867
# 47   DCS Compton (ENG)  1937-1957       78   131  15   5807
# 48   DCS Compton (ENG)  1937-1957       78   131  15   5807
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 12                319  57.40       22882                54.19   38  52  11
# 13                319  57.40       22882                54.19   38  52  11
# 20                251  54.88       17913                51.78   33  37  11
# 21                251  54.88       17913                51.78   33  37  11
# ...

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['KC Sangakkara (SL)', 'KS Williamson (NZ)', 'S Chanderpaul (WI)', 'DCS Compton (ENG)'])]
# Out:
#                 Player       Span  Matches  Inns  NO   Runs  \
# 12  KC Sangakkara (SL)  2000-2015      134   233  17  12400
# 20  KS Williamson (NZ)  2010-2024      105   186  17   9276
# 37  S Chanderpaul (WI)  1994-2015      164   280  49  11867
# 47   DCS Compton (ENG)  1937-1957       78   131  15   5807
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 12                319  57.40       22882                54.19   38  52  11
# 20                251  54.88       17913                51.78   33  37  11
# 37               203*  51.37       27395                43.31   30  66  15
# 47                278  50.06       2731+                38.81   17  28  10
#
#       4s  6s
# 12  1491  51
# 20  1031  27
# 37  1285  36
# 47  342+   3

# %% [markdown]
# # Spilit up Span into Satart and End Date

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2025]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat = '-').str[0]
# Out:
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1930
#       ...
# 61    1965
# 62    2002
# 63    1924
# 64    1930
# 65    1928
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat = '-').str[1]
# Out:
# 0     1948
# 1     2025
# 2     2016
# 3     1970
# 4     1954
#       ...
# 61    1981
# 62    2014
# 63    1934
# 64    1938
# 65    1934
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  NO  Runs Highest_Inns_Score  \
# 0  DG Bradman (AUS)  1928-1948       52    80  10  6996                334
# 1  PHKD Mendis (SL)  2022-2025       12    21   2  1184               182*
# 2    AC Voges (AUS)  2015-2016       20    31   7  1485               269*
# 3   RG Pollock (SA)  1963-1970       23    41   4  2256                274
# 4   GA Headley (WI)  1930-1954       22    40   4  2190               270*
#
#      Ave Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0  99.94       9800+                58.60   29  13  7  626+   6        1928
# 1  62.31        1839                64.38    5   4  -   123  23        2022
# 2  61.87        2667                55.68    5   4  2   186   5        2015
# 3  60.97       1707+                54.48    7  11  1  246+  11        1963
# 4  60.83        416+                56.00   10   5  2  104+   1        1930
#
#   Final_Year
# 0       1948
# 1       2025
# 2       2016
# ...

# %% [markdown]
# ## Drop Span Cplumns

# %%
df = df.drop(['Span'] , axis= 1)

# %%
df.head()
# Out:
#              Player  Matches  Inns  NO  Runs Highest_Inns_Score    Ave  \
# 0  DG Bradman (AUS)       52    80  10  6996                334  99.94
# 1  PHKD Mendis (SL)       12    21   2  1184               182*  62.31
# 2    AC Voges (AUS)       20    31   7  1485               269*  61.87
# 3   RG Pollock (SA)       23    41   4  2256                274  60.97
# 4   GA Headley (WI)       22    40   4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        1839                64.38    5   4  -   123  23        2022
# 2        2667                55.68    5   4  2   186   5        2015
# 3       1707+                54.48    7  11  1  246+  11        1963
# 4        416+                56.00   10   5  2  104+   1        1930
#
#   Final_Year
# 0       1948
# 1       2025
# 2       2016
# 3       1970
# 4       1954

# %% [markdown]
# ## Spilit up the Country from the Player

# %%
df['Player'].str.split(pat = '(' )
# Out:
# 0      [DG Bradman , AUS)]
# 1      [PHKD Mendis , SL)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['Player'].str.split(pat = '(' ).str[0]
# Out:
# 0      DG Bradman
# 1     PHKD Mendis
# 2        AC Voges
# 3      RG Pollock
# 4      GA Headley
#           ...
# 61     KD Walters
# 62       GC Smith
# 63    WH Ponsford
# 64      SJ McCabe
# 65     DR Jardine
# Name: Player, Length: 62, dtype: object

# %%
df['Player'].str.split(pat = '(' ).str[1]
# Out:
# 0        AUS)
# 1         SL)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 61       AUS)
# 62    ICC/SA)
# 63       AUS)
# 64       AUS)
# 65       ENG)
# Name: Player, Length: 62, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(' ).str[1]

# %%
df['Country'] = df['Country'].str.split(pat = ')' ).str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1         SL
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 61       AUS
# 62    ICC/SA
# 63       AUS
# 64       AUS
# 65       ENG
# Name: Country, Length: 62, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat = '(' ).str[0]

# %%
df['Player']
# Out:
# 0      DG Bradman
# 1     PHKD Mendis
# 2        AC Voges
# 3      RG Pollock
# 4      GA Headley
#           ...
# 61     KD Walters
# 62       GC Smith
# 63    WH Ponsford
# 64      SJ McCabe
# 65     DR Jardine
# Name: Player, Length: 62, dtype: object

# %%
df.head()
# Out:
#          Player  Matches  Inns  NO  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman        52    80  10  6996                334  99.94
# 1  PHKD Mendis        12    21   2  1184               182*  62.31
# 2     AC Voges        20    31   7  1485               269*  61.87
# 3   RG Pollock        23    41   4  2256                274  60.97
# 4   GA Headley        22    40   4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        1839                64.38    5   4  -   123  23        2022
# 2        2667                55.68    5   4  2   186   5        2015
# 3       1707+                54.48    7  11  1  246+  11        1963
# 4        416+                56.00   10   5  2  104+   1        1930
#
#   Final_Year Country
# 0       1948     AUS
# 1       2025      SL
# 2       2016     AUS
# 3       1970      SA
# 4       1954      WI

# %% [markdown]
# ## Chane Data Types

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# NO                       int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                       object
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'].str.split(pat = '*' ).str[0]
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_Score, Length: 62, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*' ).str[0]

# %%
df['Highest_Inns_Score']
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_Score, Length: 62, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# NO                       int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                       object
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df = df.astype({'Rookie_Year' : 'int', 'Final_Year': 'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# NO                       int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                       object
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+' ).str[0]

# %%
df['Balls_Faced']
# Out:
# 0      9800
# 1      1839
# 2      2667
# 3      1707
# 4       416
#       ...
# 61     8662
# 62    15525
# 63     3118
# 64     3217
# 65     2110
# Name: Balls_Faced, Length: 62, dtype: object

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#              Player  Matches  Inns  NO  Runs  Highest_Inns_Score    Ave  \
# 8        ED Weekes        48    81   5  4455                 207  58.61
# 16      CL Walcott        44    74   7  3798                 220  56.68
# 58  Hon.FS Jackson        20    33   4  1415                 144  48.79
#
#    Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s  Rookie_Year  \
# 8          NaN                  0.0   15  19  6  258+   2         1948
# 16         NaN                  0.0   15  14  1  107+  11         1948
# 58         NaN                  0.0    5   6  3   51+   0         1893
#
#     Final_Year Country
# 8         1958      WI
# 16        1960      WI
# 58        1905     ENG

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# NO                       int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                       object
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %% [markdown]
# ## Build Career Length

# %%
df['Career_length'] = df['Final_Year'] -df['Rookie_Year']

# %%
df
# Out:
#           Player  Matches  Inns  NO  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80  10  6996                 334  99.94
# 1   PHKD Mendis        12    21   2  1184                 182  62.31
# 2      AC Voges        20    31   7  1485                 269  61.87
# 3    RG Pollock        23    41   4  2256                 274  60.97
# 4    GA Headley        22    40   4  2190                 270  60.83
# ..           ...      ...   ...  ..   ...                 ...    ...
# 61   KD Walters        74   125  14  5357                 250  48.26
# 62     GC Smith       117   205  13  9265                 277  48.25
# 63  WH Ponsford        29    48   4  2122                 266  48.22
# 64    SJ McCabe        39    62   5  2748                 232  48.21
# 65   DR Jardine        22    33   6  1296                 127  48.00
#
#     Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  Rookie_Year  \
# ...

# %% [markdown]
# ## Calculation

# %%
df['Career_length'].mean()
# Out:
# np.float64(12.96774193548387)

# %%
df[df['Career_length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# np.float64(47.80186046511628)

# %%
df[df['Rookie_Year'] < 1960 ]['Player'].count()
# Out:
# np.int64(23)

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('Highincountry').reset_index().sort_values('Highincountry', ascending=False)
# Out:
#     Country  Highincountry
# 5    ICC/WI            400
# 0       AUS            380
# 10       SL            374
# 11       WI            365
# 1       ENG            364
# 3   ICC/PAK            329
# 2   ICC/IND            319
# 8       PAK            313
# 9        SA            278
# 4    ICC/SA            277
# 7        NZ            251
# 6       IND            248
# 12      ZIM            232

# %%
import matplotlib.pyplot as plt

# Create a figure with a specific size
plt.figure(figsize=(10, 8))

# Plot a histogram of 'Career_year'
plt.hist(df['Career_length'], color='green', bins=5)  # You can adjust the number of bins

# Add labels and title for clarity
plt.xlabel('Career length')
plt.ylabel('Frequency')
plt.title('Histogram of Career length')

# Show the plot
plt.show()
